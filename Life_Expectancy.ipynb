# %%
import pandas as pd
df=pd.read_csv("/Users/sunitjadeja/Desktop/Python/Life Expectancy Data.csv")
# df
#df.columns
# df.head(20)
#print (df.info)
# print (df.shape)
df.dtypes
df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
df=pd.read_csv("/Users/sunitjadeja/Desktop/Python/Life Expectancy Data(1).csv")
# df
#df.columns
# df.head(20)
#print (df.info)
print (df.shape)
# df.dtypes
df
# Out:
# (2938, 23)
#           Country  Year      Status Continent  Life expectancy   \
# 0     Afghanistan  2015  Developing      Asia              65.0
# 1     Afghanistan  2014  Developing      Asia              59.9
# 2     Afghanistan  2013  Developing      Asia              59.9
# 3     Afghanistan  2012  Developing      Asia              59.5
# 4     Afghanistan  2011  Developing      Asia              59.2
# ...           ...   ...         ...       ...               ...
# 2933     Zimbabwe  2004  Developing    Africa              44.3
# 2934     Zimbabwe  2003  Developing    Africa              44.5
# 2935     Zimbabwe  2002  Developing    Africa              44.8
# 2936     Zimbabwe  2001  Developing    Africa              45.3
# 2937     Zimbabwe  2000  Developing    Africa              46.0
#
#       Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 0               263.0             62     0.01               71.279624
# ...

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from numpy import cov
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression

# %%
print (df.isnull().sum())
sns.heatmap(df.isnull(),cbar=True)
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Continent                            0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64
# <AxesSubplot:>

# %%
X=df.iloc[:,0:23]
xdf=X.fillna(X.rolling(67,min_periods=3).mean())
print (xdf.isnull().sum())
sns.heatmap(xdf.isnull(),cbar=True)
xdf.to_csv("/Users/sunitjadeja/Desktop/Life_Expe.csv")
# Out:
# Country                            0
# Year                               0
# Status                             0
# Continent                          0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
xdf.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2938.000000      2938.000000    2938.000000
# mean   2007.518720         69.220747       164.799096      30.303948
# std       4.613841          9.508886       124.090850     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.125000        74.000000       0.000000
# 50%    2008.000000         72.000000       144.000000       3.000000
# 75%    2012.000000         75.600000       227.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2938.000000             2938.000000  2938.000000    2938.000000
# mean      4.601368              738.251295    80.571107    2419.592240
# std       3.947091             1987.914858    22.986574   11467.272489
# ...

# %%
xdf.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Continent', 'Life expectancy ',
#        'Adult Mortality', 'infant deaths', 'Alcohol', 'percentage expenditure',
#        'Hepatitis B', 'Measles ', ' BMI ', 'under-five deaths ', 'Polio',
#        'Total expenditure', 'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
df.Status.value_counts()
# Out:
# Developing    2426
# Developed      512
# Name: Status, dtype: int64

# %%
inter = df.interpolate(order=2)
inter.describe()
#df["columns name"].interpolate(method=typee of interpolation, order=2)
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2938.000000      2938.000000    2938.000000
# mean   2007.518720         69.214874       164.744554      30.303948
# std       4.613841          9.510819       124.226596     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.000000       144.000000       3.000000
# 75%    2012.000000         75.600000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2938.000000             2938.000000  2938.000000    2938.000000
# mean      4.550179              738.251295    78.528421    2419.592240
# std       3.994827             1987.914858    25.183772   11467.272489
# ...

# %%
print (df.dtypes)
# print (df.info)
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
#  BMI                               float64
# under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
#  HIV/AIDS                          float64
# GDP                                float64
# Population                         float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# ...

# %%
df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
xdf.describe()
# Out:
#        Life expectancy   Adult Mortality  infant deaths      Alcohol  \
# count       2938.000000      2938.000000    2938.000000  2938.000000
# mean          69.220681       164.798580      30.303948     4.600554
# std            9.509092       124.094224     117.926501     3.949021
# min           36.300000         1.000000       0.000000     0.010000
# 25%           63.125000        74.000000       0.000000     1.080000
# 50%           72.000000       144.000000       3.000000     3.830000
# 75%           75.600000       227.000000      22.000000     7.530000
# max           89.000000       723.000000    1800.000000    17.870000
#
#        percentage expenditure  Hepatitis B       Measles          BMI   \
# count             2938.000000  2938.000000    2938.000000  2938.000000
# mean               738.251295    80.570822    2419.592240    38.299364
# std               1987.914858    22.995861   11467.272489    19.929732
# ...

# %%
xdf.skew()
# Out:
# Life expectancy                    -0.638204
# Adult Mortality                     1.175912
# infant deaths                       9.786963
# Alcohol                             0.599978
# percentage expenditure              4.652051
# Hepatitis B                        -2.005728
# Measles                             9.441332
#  BMI                               -0.217267
# under-five deaths                   9.495065
# Polio                              -2.090803
# Total expenditure                   0.619491
# Diphtheria                         -2.064099
#  HIV/AIDS                           5.396112
# GDP                                 3.281018
# Population                         16.991215
#  thinness  1-19 years               1.698908
#  thinness 5-9 years                 1.760481
# Income composition of resources    -1.193775
# Schooling                          -0.655056
# dtype: float64

# %%
class_count=xdf.groupby("Status").size()
class_count
# Out:
# Status
# Developed      512
# Developing    2426
# dtype: int64

# %%
# X=df.iloc[:,3:22]
corr = xdf.corr()
corr
cmap = sns.diverging_palette(220, 10, as_cmap=True)
plt.figure(figsize=(30, 20))
plt.title('Pearson Correlation of Features', y=1, size=40)
sns.heatmap(corr,vmax=1.0,cmap=cmap,square=True,linewidths=0.5,annot=True)
# Out:
# <AxesSubplot:title={'center':'Pearson Correlation of Features'}>

# %%
X=df.iloc[:,3:22]
corr = X.corr()
corr
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(15, 15))
plt.title('Pearson Correlation of Features', y=1, size=40)
# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1.0, center=0,
            square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:title={'center':'Pearson Correlation of Features'}>

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.boxplot(y='Life expectancy ', x='Status', 
                 data=df, 
                 palette="colorblind",
                 )
# Out:
# <AxesSubplot:xlabel='Status', ylabel='Life expectancy '>

# %%
df1 = df[df['Year'].isin([2000,2015])]

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.boxplot(y='Life expectancy ', x='Status', 
                 data=df1, 
                 palette="colorblind",hue="Year"
                 )
# Out:
# <AxesSubplot:xlabel='Status', ylabel='Life expectancy '>

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.boxplot(y='Life expectancy ', x='Status', 
                 data=df1, 
                 palette="rainbow", 
                  hue='Year')
sns.stripplot(y='Life expectancy ', x='Status', 
                   data=df1, 
                   jitter=True,
                   dodge=True, 
                   marker='o', 
                   alpha=0.5,
                   hue='Year',
                   color='red')
# Out:
# <AxesSubplot:xlabel='Status', ylabel='Life expectancy '>

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.boxplot(x='Hepatitis B', y='Status', 
                 data=df1, 
                 palette="colorblind",hue="Year"
                 )
# Out:
# <AxesSubplot:xlabel='Hepatitis B', ylabel='Status'>

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.barplot(data = df, x = "Status", y = 'GDP')
print(plt.show())
# Out:
# None

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.boxplot(y='GDP', x='Status', 
                 data=df1, 
                 palette="colorblind", 
                  hue='Year')
sns.stripplot(y='GDP', x='Status', 
                   data=df1, 
                   jitter=True,
                   dodge=True, 
                   marker='o', 
                   alpha=0.5,
                   hue='Year',
                   color='red')
# Out:
# <AxesSubplot:xlabel='Status', ylabel='GDP'>

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.barplot(data = df1, x = "Status", y ="Diphtheria " )
print(plt.show())
# Out:
# None

# %%
sns.pairplot(
    df,
    x_vars=['Life expectancy ','GDP','Schooling','Total expenditure'],
    y_vars=['Hepatitis B','Measles ',' BMI ','Polio','Diphtheria ',' HIV/AIDS'],hue="Status",height=3
)

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.boxplot(y='Life expectancy ', x="Hepatitis B (CAT)", 
                 data=df1, 
                 palette="coolwarm", 
                  )
sns.stripplot(y='Life expectancy ', x="Hepatitis B (CAT)", 
                   data=df1, 
                   jitter=True,
                   dodge=True, 
                   marker='x', 
                   alpha=0.5,
                   )
# Out:
# <AxesSubplot:xlabel='Hepatitis B (CAT)', ylabel='Life expectancy '>

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.boxplot(y='Life expectancy ', x='Hepatitis B (CAT)', 
                 data=df1, 
                 palette="colorblind",
                 )
# Out:
# <AxesSubplot:xlabel='Hepatitis B (CAT)', ylabel='Life expectancy '>

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.boxplot(y='Life expectancy ', x='Polio (CAT)', 
                 data=df1, 
                 palette="colorblind",
                 )
# Out:
# <AxesSubplot:xlabel='Polio (CAT)', ylabel='Life expectancy '>

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.jointplot(y=df['percentage expenditure'], x= df['Life expectancy '],hue= "Status",data=df)

# %%
sns.set({'figure.figsize':(500,500)})
sns.jointplot(y=df['GDP'], x= df['Life expectancy '],hue="Status",data=df)

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(df['Life expectancy '], bins=10)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='Life expectancy ', ylabel='Density'>

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(df['Life expectancy '], kde = False, bins=25)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='Life expectancy '>

# %%
sns.set(rc={'figure.figsize':(500,500)})
sns.jointplot(y=df['Adult Mortality'], x= df['Life expectancy '],data=df,kind='reg')

# %%
sns.set(rc={'figure.figsize':(500,500)})
sns.jointplot(x=df["GDP"], y= df["percentage expenditure"],data=df,kind='reg')

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.boxplot(y='Life expectancy ', x='Continent', 
                 data=df, 
                 palette="rainbow",
                 )
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='Life expectancy '>

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.boxplot(y='Adult Mortality', x='Continent', 
                 data=df, 
                 palette="rainbow_r",
                 )
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='Adult Mortality'>
